# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Reading 1 million rows 
properties_df = pd.read_csv("../input/properties_2016.csv" ,nrows=1000000,low_memory=False)

properties_df.shape
# Out:
# (1000000, 58)

# %%
prop_df = properties_df.copy()
# For calculating Person coefficient putting Null values as 0
prop_df.fillna(0,inplace=True)

#1. Pearson Co-Relation Analysis

#Created an array of ineresting features on which the Pearson coefficient will be calculated
data = np.array([prop_df['bathroomcnt'],prop_df['bedroomcnt'],prop_df['finishedsquarefeet12'],prop_df['finishedsquarefeet15'],prop_df['calculatedfinishedsquarefeet'],prop_df['lotsizesquarefeet'],prop_df['numberofstories'],prop_df['roomcnt'],prop_df['unitcnt'],prop_df['taxvaluedollarcnt'],prop_df['taxamount'],prop_df['structuretaxvaluedollarcnt'],prop_df['landtaxvaluedollarcnt']])
#data = prop_df[['bathroomcnt','bedroomcnt','finishedsquarefeet12','finishedsquarefeet15','calculatedfinishedsquarefeet','lotsizesquarefeet','numberofstories','roomcnt','unitcnt','taxvaluedollarcnt','taxamount','structuretaxvaluedollarcnt','landtaxvaluedollarcnt']].copy()
cols = ['bathroomcnt','bedroomcnt','finishedsquarefeet12','finishedsquarefeet15','calculatedfinishedsquarefeet','lotsizesquarefeet','numberofstories','roomcnt','unitcnt','taxvaluedollarcnt','taxamount','structuretaxvaluedollarcnt','landtaxvaluedollarcnt']
corr = np.corrcoef(data)
plt.figure(figsize=(13,13))
sns.heatmap(corr, annot=True ,xticklabels=cols , yticklabels=cols)

# %%
#From the heatmap we infer that features like taxamount,taxvaluedollarcnt,structuredtaxvaluedollarcnt,landtaxvaluedollarcnt,
#caluclatedfinishedsquarefeet and finishedsquarefeet12 are the most co-related variables and we will explore them further and see how they fare with the 
#models

#Negative co-relation is of lotsizesquarefeet feature with the other features

#2. Informative Plots

#a.Count Plot

plt.figure(figsize = (12,12))
sns.countplot(x="bedroomcnt", data=prop_df)

# %%
#From the above graph we infer that out of the parcels sold majority of them have 3 bedrooms , in our sample set almost 40000  parcels sold with 3 bedrooms.
#This indicate that 3 bedroom parcels are the most preferred among buyers.

#b.Scatter Plot

plt.figure(figsize = (12,12))
plt.scatter(x='latitude',y='longitude',data=prop_df)

# %%
#Another interesting pair of variables are latitude and longitude of the parcel lot. When mapped as scatter plot they roughly show the
#area of the region on map where al these parcels belong to. This area resembles the Los Angeles,California bay area location , thus confirming 
#that the properties mentioned confirm to their latitude and longitude values with a few exceptions.

#c. Line chart 

plt.figure(figsize = (12,12))
plt.plot(np.sort(prop_df['yearbuilt']))
plt.ylim([1900,2020])
# Out:
# (1900, 2020)

# %%
#The above charts the number of parcels built in a year from 1900-2020. We can see that majoriy of the plots were built after 1940.


#Lets evaluate the train csv file
training_df = pd.read_csv("../input/train_2016_v2.csv", low_memory=False)
# merging train and properties files
train_df = pd.merge(training_df,properties_df,how='left' , on='parcelid')
train_df.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  \
# 0  11016594    0.0276      2016-01-01                    NaN
# 1  14366692   -0.1684      2016-01-01                    NaN
# 2  12098116   -0.0040      2016-01-01                    NaN
# 3  12643413    0.0218      2016-01-02                    NaN
# 4  14432541   -0.0050      2016-01-02                    NaN
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          NaN         NaN
# 1                       NaN           NaN          3.5         4.0
# 2                       NaN           NaN          NaN         NaN
# 3                       NaN           NaN          NaN         NaN
# 4                       NaN           NaN          NaN         NaN
#
#    buildingclasstypeid  buildingqualitytypeid         ...           \
# 0                  NaN                    NaN         ...
# 1                  NaN                    NaN         ...
# 2                  NaN                    NaN         ...
# 3                  NaN                    NaN         ...
# 4                  NaN                    NaN         ...
#
#    numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0              NaN            NaN                         NaN
# 1              NaN            NaN                    346458.0
# 2              NaN            NaN                         NaN
# 3              NaN            NaN                         NaN
# 4              NaN            NaN                         NaN
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0                NaN             NaN                    NaN        NaN
# 1           585529.0          2015.0               239071.0   10153.02
# 2                NaN             NaN                    NaN        NaN
# 3                NaN             NaN                    NaN        NaN
# 4                NaN             NaN                    NaN        NaN
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
# 2                 NaN                 NaN                  NaN
# 3                 NaN                 NaN                  NaN
# 4                 NaN                 NaN                  NaN
#
# [5 rows x 60 columns]

# %%
#d. Bar plot

#Extracting transaction month from transaction date
train_df['transactionMonth'] = pd.DatetimeIndex(train_df['transactiondate']).month
plt.figure(figsize= (12,12))
sns.countplot(x="transactionMonth",data=train_df,color='blue')

# %%
#The above chart shows that most of the parcels were sold before October. This could be due to the fact that during winters
#people dont engage in house hunting and purchasig activitie or maybe the activties were not recorded correctly for Ocober as there
#were not enough staff to work on it

#As the properties file has a lot of Null values we will replace them with the means of the corresponding feature for further calculation
mean_values = train_df.mean(axis=0)
train_new_df = train_df.fillna(mean_values, inplace=True)

# checking thhe types of all columns
train_new_df.dtypes
# Out:
# parcelid                          int64
# logerror                        float64
# transactiondate                  object
# airconditioningtypeid           float64
# architecturalstyletypeid        float64
# basementsqft                    float64
# bathroomcnt                     float64
# bedroomcnt                      float64
# buildingclasstypeid             float64
# buildingqualitytypeid           float64
# calculatedbathnbr               float64
# decktypeid                      float64
# finishedfloor1squarefeet        float64
# calculatedfinishedsquarefeet    float64
# finishedsquarefeet12            float64
# finishedsquarefeet13            float64
# finishedsquarefeet15            float64
# finishedsquarefeet50            float64
# finishedsquarefeet6             float64
# fips                            float64
# fireplacecnt                    float64
# fullbathcnt                     float64
# garagecarcnt                    float64
# garagetotalsqft                 float64
# hashottuborspa                   object
# heatingorsystemtypeid           float64
# latitude                        float64
# longitude                       float64
# lotsizesquarefeet               float64
# poolcnt                         float64
# poolsizesum                     float64
# pooltypeid10                    float64
# pooltypeid2                     float64
# pooltypeid7                     float64
# propertycountylandusecode        object
# propertylandusetypeid           float64
# propertyzoningdesc               object
# rawcensustractandblock          float64
# regionidcity                    float64
# regionidcounty                  float64
# regionidneighborhood            float64
# regionidzip                     float64
# roomcnt                         float64
# storytypeid                     float64
# threequarterbathnbr             float64
# typeconstructiontypeid          float64
# unitcnt                         float64
# yardbuildingsqft17              float64
# yardbuildingsqft26              float64
# yearbuilt                       float64
# numberofstories                 float64
# fireplaceflag                    object
# structuretaxvaluedollarcnt      float64
# taxvaluedollarcnt               float64
# assessmentyear                  float64
# landtaxvaluedollarcnt           float64
# taxamount                       float64
# taxdelinquencyflag               object
# taxdelinquencyyear              float64
# censustractandblock             float64
# dtype: object

# %%
#Finding the pearson coeficient of all the features with log error
#e. Bar Plot

features = []
corrvalue = []
for columns in train_new_df.columns:
    if columns not in ['logerror'] and train_new_df[columns].dtype == 'float64':
        features.append(columns)
        
        corrvalue.append(np.corrcoef(train_new_df[columns].values,train_new_df.logerror.values)[0,1])
width = 0.9
corr_df = pd.DataFrame({'col_labels':features, 'corr_values':corrvalue})
corr_df = corr_df.sort_values(by='corr_values')
plt.figure(figsize = (10,15))

sns.barplot(x='corr_values',y='col_labels',data=corr_df)
# Out:
# C:\Users\Parthu\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3162: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Parthu\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3163: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
#As expected few of the features like finishedsquarefeet12 , structuredtaxvaluedollarcnt , calculatedbathnbr have higher 
#relation with the log error. But suprisingly taxamounts have negative correlation with log eror which is contradicting our earlier observation.
#This could be due to the mean values that were filled for all nulls.


#3. Linear Regression Model

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

#We will take the best features from the properties based on the co relation graphs i.e heat map and bar plot plotted above
train = train_new_df.copy()
train = train.filter(['calculatedfinishedsquarefeet','finishedsquarefeet12','bedroomcnt','calculatedbathnbr','fullbathcnt','bathroomcnt','structuretaxvaluedollarcnt'])
# Taking train dataset as 89275 rows and remaining 1000 rows are test dataset
train_Y = train_new_df['logerror'].values[:89275]
train_X = train[:89275]
test_X = train[89275:]
test_Y = train_new_df['logerror'].values[89275:]

linear_reg=linear_model.LinearRegression()

linear_reg.fit(train_X,train_Y)
test_Y_predict=linear_reg.predict(test_X)

# The coefficients
print('Coefficients: \n', linear_reg.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(test_Y, test_Y_predict))
# Explained variance score
print('Variance score: %.2f' % r2_score(test_Y, test_Y_predict))
# Out:
# Coefficients:
#  [  4.97282158e-06   2.26600024e-06   2.10792768e-03   8.09088832e-03
#    5.67760985e-04  -1.10363672e-02  -5.74476220e-09]
# Mean squared error: 0.03
# Variance score: -0.01

# %%
#The Linear model gave better coefficients , the mean sqaure error and variance score are fine for the data used.

#Following table shows the features and their coefficients
features_df = pd.DataFrame({'Features':test_X.columns.values, 'Coefficients':linear_reg.coef_})

# %%
features_df
# Out:
#    Coefficients                      Features
# 0  5.885116e-06  calculatedfinishedsquarefeet
# 1  1.166460e-06          finishedsquarefeet12
# 2  2.034077e-03                    bedroomcnt
# 3  1.078454e-02             calculatedbathnbr
# 4 -3.266441e-04                   fullbathcnt
# 5 -1.272865e-02                   bathroomcnt
# 6 -4.744065e-09    structuretaxvaluedollarcnt

# %%
#From the table it is clear that calculatedbathnbr has the maximum co-relation with logerror. Lets plot a scatter map for this feature

plt.figure(figsize = (12,12))
plt.scatter(train_df.calculatedbathnbr,train_df.logerror)

# %%
#The scatter plot indicates that log error narrows down with increase in calculatedbathnbr thus justifying their linear relationship.
#Hence based on linear model calculatedbathnbr seems to be the most important feature so far.

#4. Random Forest Regression Model
#To understand the data set more lets first evaluate al the mising values

properties_df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# 0                NaN         NaN         ...                       NaN
# 1                NaN         NaN         ...                       NaN
# 2                NaN         NaN         ...                       NaN
# 3                NaN         NaN         ...                       1.0
# 4                NaN         NaN         ...                       NaN
#
#    fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0            NaN                         NaN                9.0
# 1            NaN                         NaN            27516.0
# 2            NaN                    650756.0          1413387.0
# 3            NaN                    571346.0          1156834.0
# 4            NaN                    193796.0           433491.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0            2015                    9.0        NaN                 NaN
# 1            2015                27516.0        NaN                 NaN
# 2            2015               762631.0   20800.37                 NaN
# 3            2015               585488.0   14557.57                 NaN
# 4            2015               239695.0    5725.17                 NaN
#
#    taxdelinquencyyear  censustractandblock
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 58 columns]

# %%
missing_values = properties_df.isnull().sum()
missing_values
# Out:
# parcelid                             0
# airconditioningtypeid           726690
# architecturalstyletypeid        998025
# basementsqft                    999464
# bathroomcnt                          8
# bedroomcnt                           3
# buildingclasstypeid             995720
# buildingqualitytypeid           348070
# calculatedbathnbr                39675
# decktypeid                      994261
# finishedfloor1squarefeet        931156
# calculatedfinishedsquarefeet     14760
# finishedsquarefeet12             88764
# finishedsquarefeet13            997333
# finishedsquarefeet15            936051
# finishedsquarefeet50            931156
# finishedsquarefeet6             992611
# fips                                 0
# fireplacecnt                    894624
# fullbathcnt                      39675
# garagecarcnt                    703049
# garagetotalsqft                 703049
# hashottuborspa                  976824
# heatingorsystemtypeid           392310
# latitude                             0
# longitude                            0
# lotsizesquarefeet                89031
# poolcnt                         825598
# poolsizesum                     990435
# pooltypeid10                    987610
# pooltypeid2                     989214
# pooltypeid7                     836384
# propertycountylandusecode          292
# propertylandusetypeid                0
# propertyzoningdesc              334648
# rawcensustractandblock               0
# regionidcity                     17205
# regionidcounty                       0
# regionidneighborhood            610841
# regionidzip                        800
# roomcnt                              9
# storytypeid                     999465
# threequarterbathnbr             895409
# typeconstructiontypeid          997778
# unitcnt                         334892
# yardbuildingsqft17              972648
# yardbuildingsqft26              999085
# yearbuilt                        16302
# numberofstories                 770582
# fireplaceflag                   998255
# structuretaxvaluedollarcnt       14750
# taxvaluedollarcnt                10656
# assessmentyear                       0
# landtaxvaluedollarcnt            19133
# taxamount                         6659
# taxdelinquencyflag              981137
# taxdelinquencyyear              981137
# censustractandblock              21653
# dtype: int64

# %%
#Plotting a grahph of features with the missing count
missing_sorted = missing_values.sort_values(ascending=False).to_frame().reset_index()
missing_sorted.columns = ['Features','Missing_count']
plt.figure(figsize = (10,15))
sns.barplot(x="Missing_count",y="Features",data=missing_sorted)

# %%
#The data frame has a lot of missing values mostly with categorical fields , however the fields that we were interested n our linear 
#model have less missing values.

#We will now create a merged dataframe for the Random Forest Regression

train2_df = pd.merge(training_df,properties_df,how='left' , on='parcelid')
train2_df.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  \
# 0  11016594    0.0276      2016-01-01                    NaN
# 1  14366692   -0.1684      2016-01-01                    NaN
# 2  12098116   -0.0040      2016-01-01                    NaN
# 3  12643413    0.0218      2016-01-02                    NaN
# 4  14432541   -0.0050      2016-01-02                    NaN
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          NaN         NaN
# 1                       NaN           NaN          3.5         4.0
# 2                       NaN           NaN          NaN         NaN
# 3                       NaN           NaN          NaN         NaN
# 4                       NaN           NaN          NaN         NaN
#
#    buildingclasstypeid  buildingqualitytypeid         ...           \
# 0                  NaN                    NaN         ...
# 1                  NaN                    NaN         ...
# 2                  NaN                    NaN         ...
# 3                  NaN                    NaN         ...
# 4                  NaN                    NaN         ...
#
#    numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0              NaN            NaN                         NaN
# 1              NaN            NaN                    346458.0
# 2              NaN            NaN                         NaN
# 3              NaN            NaN                         NaN
# 4              NaN            NaN                         NaN
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0                NaN             NaN                    NaN        NaN
# 1           585529.0          2015.0               239071.0   10153.02
# 2                NaN             NaN                    NaN        NaN
# 3                NaN             NaN                    NaN        NaN
# 4                NaN             NaN                    NaN        NaN
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
# 2                 NaN                 NaN                  NaN
# 3                 NaN                 NaN                  NaN
# 4                 NaN                 NaN                  NaN
#
# [5 rows x 60 columns]

# %%
#Will fill the missing values with median value for all the columns

median = train2_df.median(axis=0)
train_new_df2 = train2_df.fillna(median, inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

train = train_new_df2.copy()
# We will drop the features which had higher frequency of missing values along with the columns of train df for the test df
train = train.drop(['parcelid', 'logerror', 'transactiondate','hashottuborspa', 'propertycountylandusecode', 'propertyzoningdesc', 'fireplaceflag', 'taxdelinquencyflag'],axis =1)
train_Y = list(train_new_df['logerror'].values[:89275])
train_X = train[:89275]
test_X = train[89275:]
test_Y = train_new_df['logerror'].values[89275:]

train_X.head()
# Out:
#    airconditioningtypeid  architecturalstyletypeid  basementsqft  bathroomcnt  \
# 0                    1.0                       7.0         683.0          2.0
# 1                    1.0                       7.0         683.0          3.5
# 2                    1.0                       7.0         683.0          2.0
# 3                    1.0                       7.0         683.0          2.0
# 4                    1.0                       7.0         683.0          2.0
#
#    bedroomcnt  buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  \
# 0         3.0                  4.0                    7.0                2.0
# 1         4.0                  4.0                    7.0                3.5
# 2         3.0                  4.0                    7.0                2.0
# 3         3.0                  4.0                    7.0                2.0
# 4         3.0                  4.0                    7.0                2.0
#
#    decktypeid  finishedfloor1squarefeet         ...           \
# 0        66.0                    1242.0         ...
# 1        66.0                    1242.0         ...
# 2        66.0                    1242.0         ...
# 3        66.0                    1242.0         ...
# 4        66.0                    1242.0         ...
#
#    yardbuildingsqft26  yearbuilt  numberofstories  structuretaxvaluedollarcnt  \
# 0               200.0     1969.0              1.0                    131483.0
# 1               200.0     2014.0              1.0                    346458.0
# 2               200.0     1969.0              1.0                    131483.0
# 3               200.0     1969.0              1.0                    131483.0
# 4               200.0     1969.0              1.0                    131483.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           340657.0          2015.0               192758.0    4521.84
# 1           585529.0          2015.0               239071.0   10153.02
# 2           340657.0          2015.0               192758.0    4521.84
# 3           340657.0          2015.0               192758.0    4521.84
# 4           340657.0          2015.0               192758.0    4521.84
#
#    taxdelinquencyyear  censustractandblock
# 0                14.0         6.037604e+13
# 1                14.0         6.037604e+13
# 2                14.0         6.037604e+13
# 3                14.0         6.037604e+13
# 4                14.0         6.037604e+13
#
# [5 rows x 52 columns]

# %%
#Training the Random Forest regressor
reg = RandomForestRegressor(n_jobs=2, random_state=0)
reg.fit(train_X,train_Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=2,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
#predicting the log error values
test_Y_reg = reg.predict(test_X)
# The coefficients
print('Coefficients: \n', reg.feature_importances_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(test_Y, test_Y_reg))
# Explained variance score
print('Variance score: %.2f' % r2_score(test_Y, test_Y_reg))
# Out:
# Coefficients:
#  [  8.06558304e-04   6.39109189e-05   4.20685202e-04   1.07766561e-02
#    1.76314234e-02   0.00000000e+00   1.23827797e-02   7.29782459e-03
#    0.00000000e+00   3.68049313e-03   5.59923605e-02   4.99404800e-02
#    6.33336980e-05   1.33087228e-02   3.99293230e-03   3.07667644e-03
#    2.20416549e-03   4.32143050e-04   1.09143157e-02   2.47473412e-03
#    1.09976543e-02   4.71810377e-03   8.84078575e-02   7.84533512e-02
#    6.95266125e-02   0.00000000e+00   8.71569505e-04   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   9.40340084e-03   2.75594275e-02
#    2.82194714e-02   4.32199030e-03   2.90813776e-02   4.72041362e-02
#    3.79860904e-03   0.00000000e+00   8.89456961e-04   0.00000000e+00
#    2.64073302e-03   2.27495101e-03   1.60972448e-04   5.81635653e-02
#    1.43107719e-03   8.88209089e-02   6.67071734e-02   0.00000000e+00
#    6.94654817e-02   7.97246334e-02   4.78015269e-03   2.69171372e-02]
# Mean squared error: 0.03
# Variance score: -0.10

# %%
#Suprsingly the mean square error is the same for Linear and Random Forest Regression model .However the coeeficients are better now

#Creating table for Features and Corelation coefficients
features_df = pd.DataFrame({'Features':test_X.columns.values, 'Coefficients':reg.feature_importances_})
features_df
# Out:
#     Coefficients                      Features
# 0       0.000807         airconditioningtypeid
# 1       0.000064      architecturalstyletypeid
# 2       0.000421                  basementsqft
# 3       0.010777                   bathroomcnt
# 4       0.017631                    bedroomcnt
# 5       0.000000           buildingclasstypeid
# 6       0.012383         buildingqualitytypeid
# 7       0.007298             calculatedbathnbr
# 8       0.000000                    decktypeid
# 9       0.003680      finishedfloor1squarefeet
# 10      0.055992  calculatedfinishedsquarefeet
# 11      0.049940          finishedsquarefeet12
# 12      0.000063          finishedsquarefeet13
# 13      0.013309          finishedsquarefeet15
# 14      0.003993          finishedsquarefeet50
# 15      0.003077           finishedsquarefeet6
# 16      0.002204                          fips
# 17      0.000432                  fireplacecnt
# 18      0.010914                   fullbathcnt
# 19      0.002475                  garagecarcnt
# 20      0.010998               garagetotalsqft
# 21      0.004718         heatingorsystemtypeid
# 22      0.088408                      latitude
# 23      0.078453                     longitude
# 24      0.069527             lotsizesquarefeet
# 25      0.000000                       poolcnt
# 26      0.000872                   poolsizesum
# 27      0.000000                  pooltypeid10
# 28      0.000000                   pooltypeid2
# 29      0.000000                   pooltypeid7
# 30      0.009403         propertylandusetypeid
# 31      0.027559        rawcensustractandblock
# 32      0.028219                  regionidcity
# 33      0.004322                regionidcounty
# 34      0.029081          regionidneighborhood
# 35      0.047204                   regionidzip
# 36      0.003799                       roomcnt
# 37      0.000000                   storytypeid
# 38      0.000889           threequarterbathnbr
# 39      0.000000        typeconstructiontypeid
# 40      0.002641                       unitcnt
# 41      0.002275            yardbuildingsqft17
# 42      0.000161            yardbuildingsqft26
# 43      0.058164                     yearbuilt
# 44      0.001431               numberofstories
# 45      0.088821    structuretaxvaluedollarcnt
# 46      0.066707             taxvaluedollarcnt
# 47      0.000000                assessmentyear
# 48      0.069465         landtaxvaluedollarcnt
# 49      0.079725                     taxamount
# 50      0.004780            taxdelinquencyyear
# 51      0.026917           censustractandblock

# %%
#Further filtering the dataset with the highest corealtions from the above table and training the model again

train = train.filter(['calculatedfinishedsquarefeet','finishedsquarefeet12','latitude','longitude','lotsizesquarefeet','yearbuilt','structuretaxvaluedollarcnt','taxvaluedollarcnt','landtaxvaluedollarcnt','taxamount'])
train_Y = list(train_new_df['logerror'].values[:89275])
train_X = train[:89275]
test_X = train[89275:]
test_Y = train_new_df['logerror'].values[89275:]
train_X.head()
# Out:
#    calculatedfinishedsquarefeet  finishedsquarefeet12    latitude  \
# 0                        1542.0                1520.0  34021700.0
# 1                        2263.0                2263.0  33668120.0
# 2                        1542.0                1520.0  34021700.0
# 3                        1542.0                1520.0  34021700.0
# 4                        1542.0                1520.0  34021700.0
#
#      longitude  lotsizesquarefeet  yearbuilt  structuretaxvaluedollarcnt  \
# 0 -118172884.0             7197.0     1969.0                    131483.0
# 1 -117677556.0             3643.0     2014.0                    346458.0
# 2 -118172884.0             7197.0     1969.0                    131483.0
# 3 -118172884.0             7197.0     1969.0                    131483.0
# 4 -118172884.0             7197.0     1969.0                    131483.0
#
#    taxvaluedollarcnt  landtaxvaluedollarcnt  taxamount
# 0           340657.0               192758.0    4521.84
# 1           585529.0               239071.0   10153.02
# 2           340657.0               192758.0    4521.84
# 3           340657.0               192758.0    4521.84
# 4           340657.0               192758.0    4521.84

# %%
reg = RandomForestRegressor(n_jobs=2, random_state=0)
reg.fit(train_X,train_Y)
test_Y_reg = reg.predict(test_X)
# The coefficients
print('Coefficients: \n', reg.feature_importances_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(test_Y, test_Y_reg))
# Explained variance score
print('Variance score: %.2f' % r2_score(test_Y, test_Y_reg))
# Out:
# Coefficients:
#  [ 0.07995489  0.07283511  0.11070404  0.12465158  0.10254013  0.07942409
#   0.10332336  0.10406538  0.09776701  0.12473441]
# Mean squared error: 0.03
# Variance score: -0.06

# %%
#This time the coefficients again have improved but mean sqaure error is the same

features_df = pd.DataFrame({'Features':test_X.columns.values, 'Coefficients':reg.feature_importances_})
features_df
# Out:
#    Coefficients                      Features
# 0      0.079955  calculatedfinishedsquarefeet
# 1      0.072835          finishedsquarefeet12
# 2      0.110704                      latitude
# 3      0.124652                     longitude
# 4      0.102540             lotsizesquarefeet
# 5      0.079424                     yearbuilt
# 6      0.103323    structuretaxvaluedollarcnt
# 7      0.104065             taxvaluedollarcnt
# 8      0.097767         landtaxvaluedollarcnt
# 9      0.124734                     taxamount

# %%
# Plotting the highest corelated features with log error

plt.figure(figsize = (12,12))
plt.scatter(train2_df.longitude,train2_df.logerror)

# %%
plt.figure(figsize = (12,12))
plt.scatter(train2_df.taxamount,train2_df.logerror)

# %%
#Both the above plots satisfy the high corelation of these features with the log error

#5. Predicting Sample Values
sample_df=pd.read_csv("../input/sample_submission.csv" ,low_memory=False)
sample_df.shape
# Out:
# (2985217, 7)

# %%
prop_df=pd.read_csv("../input/properties_2016.csv", low_memory=False)

# %%
prop_df.shape
sample_df.head()
# Out:
#    ParcelId  201610  201611  201612  201710  201711  201712
# 0  10754147       0       0       0       0       0       0
# 1  10759547       0       0       0       0       0       0
# 2  10843547       0       0       0       0       0       0
# 3  10859147       0       0       0       0       0       0
# 4  10879947       0       0       0       0       0       0

# %%
sample_df = sample_df.rename(columns={'ParcelId': 'parcelid'})
finalTrain_df = pd.merge(sample_df,prop_df,how='left', on='parcelid')

# %%
median = finalTrain_df.median(axis=0)
finalTrain_df.fillna(median, inplace=True)

# %%
sample = finalTrain_df.copy()
sample = sample.filter(['calculatedfinishedsquarefeet','finishedsquarefeet12','latitude','longitude','lotsizesquarefeet','yearbuilt','structuretaxvaluedollarcnt','taxvaluedollarcnt','landtaxvaluedollarcnt','taxamount'])
logError = reg.predict(sample)
